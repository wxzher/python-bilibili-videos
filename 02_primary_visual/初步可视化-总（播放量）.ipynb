# %%
# 导入需要的工具包
from pyecharts.charts import Line #引入折线图
from pyecharts import options as opts
import pandas as pd
import numpy as np

# %%
# 1.读取数据
# 使用pandas读取表格数据
df = pd.read_excel('../01_data_get/Data-总（播放量）.xlsx',header=0)
# 观察是否读取成功
df
# Out:
#      Unnamed: 0    序号                                                 标题  \
# 0             0     1                                       【醒醒】中华儿女该起床了
# 1             1     2  高中数学基础与解法全集（涵盖所有）|长期更新|从零开始拯救所有学渣！通俗易懂|竞赛国一保送生...
# 2             2     3                       衡水中学“学霸”励志演讲：这世间，唯有青春与梦想不可辜负
# 3             3     4  高中数学-高一-高二-高三【高考数学专题复习】-【高考数学一轮复习】-【基础篇+提高篇】-【...
# 4             4     5                                   看完这个视频你会爱上数学的！！！
# ..          ...   ...                                                ...
# 995         995   996                            韩国高考满分的人，看中国高考为什么吃惊了三次？
# 996         996   997                        怀旧的中学时期！在苦中作乐乐乐的那几年~有让你共鸣吗？
# 997         997   998                   山东18岁艺考生河南徒手挡刀被砍伤 从警21年父亲：既欣慰又心疼
# 998         998   999                                         高考考砸了怎么办？！
# 999         999  1000                                          【光头强】高考查分
#
#                                                     网址  \
# 0    //www.bilibili.com/video/BV1m54y1Q7eQ?from=search
# 1    //www.bilibili.com/video/BV147411K7xu?from=search
# 2    //www.bilibili.com/video/BV1j4411j79x?from=search
# 3    //www.bilibili.com/video/BV1bt411C7E8?from=search
# 4    //www.bilibili.com/video/BV1e7411s7W6?from=search
# ..                                                 ...
# 995  //www.bilibili.com/video/BV1u441157ET?from=search
# 996  //www.bilibili.com/video/BV11K4y1S7uy?from=search
# 997  //www.bilibili.com/video/BV1X5411H7rj?from=search
# 998  //www.bilibili.com/video/BV1oq4y157rm?from=search
# 999  //www.bilibili.com/video/BV1NF411x743?from=search
#
#                                                     简介       up主   播放量(万)  \
# 0    愿中国青年都摆脱冷气，只是向上走，不必听自暴自弃者流的话，能做事的做事，能发声的发声，有一分...    冈部伦太郎·  3158.2万
# 1    恭喜你发现宝藏！还有3个宝藏向等你打开！\r\n@一化儿  学习化学\r\n@一生儿  学习...        一数  3057.0万
# 2                        衡水中学“学霸”励志演讲：这世间，唯有青春与梦想不可辜负！      教育思享  2048.2万
# 3    1.【高考数学一轮总复习(基础篇+提高篇)】：本视频\n2.【高中数学必修合集（同步新课）】...     数学微课帮  1618.7万
# 4    被数学爱上：BV1F741137E8\n爱上物理：BV1HX4y1g7dP\n爱上地理：BV...       诺诺雾  1436.0万
# ..                                                 ...       ...      ...
# 995  微博 ：朱丽朱丽哈哈哈\n抖音 ：  邻家韩国姐姐朱丽\n哔哩哔哩： 邻家韩国姐姐朱丽\ny...  邻家韩国姐姐朱丽    97.8万
# 996  一方面是确实是最后一个学期了以防我忘记以前中学有意思的瞬间就做了这个视频~另一方面高考一百天...       怒九笑    97.7万
# 997                                                NaN      闪电新闻    97.7万
# 998                 动画：《校园小子》\n祝高考学子高考顺利呀~\n求个三连and关注~     盖世猪猪丶    97.7万
# 999                                  视频纯属搞笑，切勿当真[doge]     淄博火车迷    97.6万
#
#         弹幕        发布时间
# 0    26.1万  2013-06-07
# 1    63.8万  2015-02-27
# 2    17.7万  2016-03-04
# 3    24.4万  2016-05-18
# 4     5.5万  2016-05-20
# ..     ...         ...
# 995   4042  2022-06-09
# 996   5144  2022-06-09
# 997    313  2022-06-09
# 998   1570  2022-06-09
# 999   3840  2022-06-09
#
# [1000 rows x 9 columns]

# %%
#2.数据预处理

# 定义转化数值型变量的函数
def transform_unit(x_col):
    """
    功能：转换数值型变量的单位
    """
    # 提取数值
    s_num = df[x_col].str.extract('(\d+\.*\d*)').astype('float')
    # 提取单位
    s_unit = df[x_col].str.extract('([\u4e00-\u9fa5]+)')
    s_unit = s_unit.replace('万', 10000).replace(np.nan, 1)
    s_multiply = s_num * s_unit
    return s_multiply

# 去重
df = df.drop_duplicates()

# 转换单位
df['watch'] = transform_unit(x_col='播放量(万)')
# 转换发布时间的数据类型为时间
df['upload_time']= pd.to_datetime(df['发布时间'],format='%Y-%m-%d')

# %%
# 3. 绘制图表

#发布热度
time_num = df.upload_time.value_counts().sort_index()   #time_num中包含的是日期，及每个日期内有多少个视频发布
# print(time_num)
time_view = df.groupby(by=['upload_time'])['watch'].sum()      #如果需要按照列A进行分组，将同一组的列B求和
# print(time_view)

# 折线图（不同的图的叠加）
line1 = Line(init_opts=opts.InitOpts(width='1350px', height='750px'))
line1.add_xaxis(time_num.index.tolist())
line1.add_yaxis('发布数量', time_num.values.tolist(),
                markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='min'),    #标记最小点及最大点
                                                        opts.MarkPointItem(type_='max')]),
                # 添加第一个轴，索引为0,（默认也是0）
                yaxis_index = 0,
                #color = "#d14a61",  # 系列 label 颜色，红色
               )
line1.add_yaxis('播放总量', time_view.values.tolist(),
                markpoint_opts=opts.MarkPointOpts(data=[opts.MarkPointItem(type_='min'),
                                                        opts.MarkPointItem(type_='max')]),
                yaxis_index=1,  # 上面的折线图图默认索引为0，这里设置折线图y 轴索引为1
                #color="#5793f3", # 系列 label 颜色蓝色
               )

#新加入一个y轴(索引值是1)下方是对其的详细配置
line1.extend_axis(
        yaxis=opts.AxisOpts(
            name="播放总量", # 坐标轴名称
            type_="value", # 坐标轴类型  'value': 数值轴，适用于连续数据。
            min_=0,  # 坐标轴刻度最小值
            max_=int(time_view.max()),  # 坐标轴刻度最大值
            position="right",  # 轴的位置  侧
            # 轴线配置
            # axisline_opts=opts.AxisLineOpts(
            #     # 轴线颜色（默认黑色）
            #     linestyle_opts=opts.LineStyleOpts(color="#5793f3")
            # ),
            # 轴标签显示格式
           #axislabel_opts=opts.LabelOpts(formatter="{value} c"),
        )
    )


#全局配置（全局配置中默认已经存在一个y轴了（默认索引值是0），要想更改此左侧的y轴必须更改此处的）
line1.set_global_opts(
                    yaxis_opts=opts.AxisOpts(
                                name="发布数量",
                                min_=0,
                                max_=int(time_num.max()),
                                position="left",
                                #offset=80, # Y 轴相对于默认位置的偏移，在相同的 position 上有多个 Y 轴的时候有用。
                                #轴线颜色
                                axisline_opts=opts.AxisLineOpts(
                                    linestyle_opts=opts.LineStyleOpts(color="#d14a61")
                                ),
                                axislabel_opts=opts.LabelOpts(formatter="{value} ml"),
                            ),
                      title_opts=opts.TitleOpts(title='高考视频发布数量/播放总量走势图', pos_left='5%'),#标题
                      xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate='-35')),         #x轴的标签倾斜度为垂直
                    )

#系列配置项，不显示标签（不会将折线上的每个点的值都在图中显示出来）
line1.set_series_opts(linestyle_opts=opts.LineStyleOpts(width=3),
                      label_opts=opts.LabelOpts(is_show=False)
                     )
# 通过网页的方式呈现动态的图形
line1.render("active.html")
# Out:
# 'd:\\Desktop\\网络数据分析 (2)\\02_primary_visual\\active.html'
