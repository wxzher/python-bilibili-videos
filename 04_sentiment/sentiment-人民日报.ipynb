# %%
#-*- codeing = utf-8 -*- 
"""情感分数的计算"""


# 1. 读取数据
import pandas as pd
data = pd.read_excel('../01_data_get/Data-人民日报.xlsx',header=0)

# %%
# 2. 获取情感分数
# 导入snownlp数据包然后进行情感分析

from snownlp import SnowNLP
data_title = data['标题']

# 建立一个列表存储情感分数
sentimentslist = []
for i in data_title:
    s = SnowNLP(i)
    print(s.sentiments)
    sentimentslist.append(s.sentiments)
# Out:
# 0.9937624766786446
# 0.9955139001009204
# 0.9935685539010872
# 0.8005216799178619
# 0.9878088882473082
# 0.8813333126017397
# 0.99776957314725
# 0.4873419138718288
# 0.9685176119521383
# 0.9683992937526545
# 0.9580832782533655
# 0.9995443846808365
# 0.9965318931575734

# %%
# 3. 存入数据
import xlwt
wb = xlwt.Workbook()
sheet = wb.add_sheet('sheet')
sheet.write(0, 0, '标题')
sheet.write(0,1, '情感分数')
count = 1
for i in sentimentslist:
    sheet.write(count,0,data_title[count-1])
    sheet.write(count,1,i)
    count += 1

wb.save('情感分数-人民日报.xlsx')

# %%
# 4. 情感分数可视化
# 越偏向0负面情绪越强烈，越偏向1正面情绪更强烈 
import matplotlib.pyplot as plt
import numpy as np
from palettable.colorbrewer.qualitative import Pastel1_7

plt.rcParams['font.sans-serif'] = 'simhei'
plt.rcParams['axes.unicode_minus']=False
plt.hist(sentimentslist, bins = np.arange(0, 1, 0.02), facecolor = 'g')
plt.xlabel('情感分数')
plt.ylabel('数量')
plt.title('B站人民日报高考视频情感分析图')
plt.savefig('B站人民日报高考视频情感分析图.jpg')
plt.show()

# %%
"""标题情感的分类"""
# 导入工具包
import matplotlib
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7
# 避免中文方格和符号乱码
plt.rcParams['font.sans-serif'] = 'simhei'
plt.rcParams['axes.unicode_minus']=False


正向标题_positive=0
负向标题_negative=0
中性标题_neutral=0

x = sentimentslist
for i in range(0,len(x)):
        if x[i]>=0.45 and x[i]<=0.55:
            中性标题_neutral+=1
        if x[i]>0.55:
            正向标题_positive+=1
        if x[i]<0.45 :
            负向标题_negative+=1



x = ['正向标题_positive', '负向标题_negative','中性标题_neutral']
y = [正向标题_positive,负向标题_negative,中性标题_neutral]
plt.pie(y,pctdistance=0.85,autopct='%.1f%%', labels=x, colors=Pastel1_7.hex_colors, wedgeprops=dict(width=0.3, edgecolor='w'))
plt.legend(x,loc='upper left')
plt.title('B站人民日报高考视频情感分类环形图')
plt.savefig('情感分类环形图-人民日报.jpg')
